# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("/Users/hitesh04/Downloads/DSBD/HousingData.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
X = df.drop(columns='MEDV')

# %%
X_filled = X.fillna(X.mean())

# %%
# Standardize
X_std = StandardScaler().fit_transform(X_filled)

# %%
X_pca = PCA(n_components=2).fit_transform(X_std)

# %%
print(X_pca[:5])
# Out:
# [[-2.12220152  0.74366378]
#  [-1.46889273  0.59288722]
#  [-2.09235355  0.59359637]
#  [-2.63507025 -0.01501437]
#  [-2.15823093  0.01737848]]

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c='blue', edgecolor='k', alpha=0.6)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Boston Housing Dataset')
plt.grid(True)
plt.show()
